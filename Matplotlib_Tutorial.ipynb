# %% [markdown]
# <a href="https://colab.research.google.com/github/SampritiMayra/Data_Analysis_prep/blob/main/Matplotlib_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Matplotlib Tutorial**

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
plt.style.use('dark_background')
plt.plot([1,2,3], [2,5,7])
plt.title("Sample Data")
plt.ylabel("Y axis")
plt.xlabel("X axis")
plt.show()
